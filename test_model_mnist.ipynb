# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_JOC/APE-GAN')
# !nvidia-smi
# !ls

# %%
# %%shell
# for ((i=12; i<=20; i++))
# do
#   echo ${i}
#   python test_model_mnist.py --data mnist --eps 0.5 --gan_path ./checkpoint/mnist/${i}.tar
# done

# %%
5-20
