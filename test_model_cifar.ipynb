# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_JOC/APE-GAN')
# !nvidia-smi
# !ls

# %%
# %%shell
# for ((i=10; i<=20; i++))
# do
#   echo ${i}
#   python test_model_cifar.py --data cifar --eps 0.01 --gan_path ./checkpoint/cifar2/${i}.tar
# done
# Out:
# 10
# Accuracy: normal 83.980003, fgsm 9.450000, ape 63.380005
# 11
# Accuracy: normal 83.980003, fgsm 9.450000, ape 60.399998
# 12
# Accuracy: normal 83.980003, fgsm 9.450000, ape 58.009998
# 13
# Accuracy: normal 83.980003, fgsm 9.450000, ape 60.079998
# 14
# Accuracy: normal 83.980003, fgsm 9.450000, ape 61.820000
# 15
# Accuracy: normal 83.980003, fgsm 9.450000, ape 61.169998
# 16
# Accuracy: normal 83.980003, fgsm 9.450000, ape 62.209999
# 17
# Accuracy: normal 83.980003, fgsm 9.450000, ape 60.070004
# 18
# Accuracy: normal 83.980003, fgsm 9.450000, ape 62.209999
# 19
# Accuracy: normal 83.980003, fgsm 9.450000, ape 62.360001
# 20
# Accuracy: normal 83.980003, fgsm 9.450000, ape 60.439999
