# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_JOC/APE-GAN')
# !nvidia-smi
# !ls

# %%
# %%shell
# python train_cifar.py --data cifar --epochs 300 --checkpoint ./checkpoint/cifar
# Out:
# tcmalloc: large alloc 2457600000 bytes == 0x5b8c000 @  0x7faf0ed6fb6b 0x7faf0ed8f379 0x7faeb211774e 0x7faeb21197b6 0x7faeed2b299d 0x7faefc9758d0 0x7faefc5f3c1a 0x566bbc 0x50a433 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x5a4c61 0x5a4fb8 0x4e012e 0x50a461 0x50beb4 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd
# tcmalloc: large alloc 2457600000 bytes == 0x5b8c000 @  0x7faf0ed6fb6b 0x7faf0ed8f379 0x7faeb211774e 0x7faeb21197b6 0x7faeed2b299d 0x7faefc9758d0 0x7faefc5f3c1a 0x566bbc 0x50a433 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x5a4c61 0x5a4fb8 0x4e012e 0x50a461 0x50beb4 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd
# 2021-02-10 11:11:06.388733: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Epoch	Gen_Loss	Dis_Loss
# ...

# %%
# %%shell
# for ((i=1; i<=300; i++))
# do
#   python test_model.py --data cifar --eps 0.5 --gan_path ./checkpoint/cifar/${i}.tar
# done
